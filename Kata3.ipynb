# %% [markdown]
# ## Kata 3

# %%
vel = 25
at = 49
if vel <= at:
    print("¡Advertencia! se acerca un asteroide")
# Out:
# ¡Advertencia! se acerca un asteroide

# %%
at = 19
if at >= 20:
    print("¡Atencion! ¿puedes ver el rayo de luz en el cielo?")
else:
    print("Buscando...")
# Out:
# Buscando...
