# %% [markdown]
# ## Kata 6

# %% [markdown]
# Ejercicio 1

# %%
# Creamos la lista planets y la mostramos
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Neptune']
print(planets)
number_of_planets = len(planets)
print('There are', number_of_planets, 'planets in the solar system.')
# Out:
# ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Neptune']
# There are 7 planets in the solar system.

# %%
# Agregamos a plutón y mostramos el último elemento
planets.append('Pluto')
number_of_planets = len(planets)
print("Of the planets " + str(number_of_planets) + " in total he last planet is" , planets[-1])
# Out:
# Of the planets 8 in total he last planet is Pluto

# %% [markdown]
# ## Ejercicio 2

# %%
# Lista de planetas

planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Neptune']

# %%
# Solicitamos el nombre de un planeta *Pista:  input()*
planet = input('Please enter the name of the planet (with a capital letter to start)')

# %%
# Busca el planeta en la lista
# Metodo index()
# error --> -1
# Sun | M V E M *J* S N | 
planet_index = planets.index(planet)

# %%
# Muestra los planetas más cercanos al sol
# slice
# Sun | (M V E M) *J* S N | 
print('Here are the planets closer than ' + planet)
print(planets[0:planet_index])
# Out:
# Here are the planets closer than Jupiter
# ['Mercury', 'Venus', 'Earth', 'Mars']

# %%
# Muestra los planetas más lejanos al sol que el que el usuario ingresó
# Sun | M V E M *J* (S N) | 
print('Here are the planets further than ' + planet)
print(planets[planet_index + 1:])
# Out:
# Here are the planets further than Jupiter
# ['Saturn', 'Neptune']
